# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Training_Data_Set.csv')
df
# Out:
#           Id   Maker    model   Location  Distance       Owner Type  \
# 0      25001   skoda  octavia  Ahmedabad        NaN          Second
# 1      25002    fiat    panda  Ahmedabad    27750.0           Third
# 2      25003     bmw       x1  Hyderabad    46000.0           Third
# 3      25004  nissan     juke     Mumbai    43949.0           Third
# 4      25005     bmw       x5     Jaipur    59524.0  Fourth & Above
# ...      ...     ...      ...        ...        ...             ...
# 53510  78511   skoda  octavia      Delhi    29334.0  Fourth & Above
# 53511  78512   skoda  octavia  Bangalore   223631.0  Fourth & Above
# 53512  78513     bmw       x1       Pune    25500.0           Third
# 53513  78514  toyota  avensis     Jaipur  1195500.0           Third
# 53514  78515     bmw       x5      Kochi   142000.0           First
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# 0                  1964          55                 1964         147.0
# ...

# %%
df.isna().sum()
# Out:
# Id                         0
# Maker                      0
# model                      0
# Location                   0
# Distance                1211
# Owner Type                 0
# manufacture_year           0
# Age of car                 0
# engine_displacement        0
# engine_power            1439
# body_type              49379
# Vroom Audit Rating         0
# transmission               0
# door_count              7534
# seat_count              8511
# fuel_type                  0
# Price                      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'body_type', 'Vroom Audit Rating', 'transmission', 'door_count',
#        'seat_count', 'fuel_type', 'Price'],
#       dtype='object')

# %%
df.drop(columns='body_type',inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                        0
# Maker                     0
# model                     0
# Location                  0
# Distance               1211
# Owner Type                0
# manufacture_year          0
# Age of car                0
# engine_displacement       0
# engine_power           1439
# Vroom Audit Rating        0
# transmission              0
# door_count             7534
# seat_count             8511
# fuel_type                 0
# Price                     0
# dtype: int64

# %%
df['Distance '].fillna(df['Distance '].mean(),inplace=True)
df['engine_power'].fillna(df['engine_power'].mean(),inplace=True)
df['door_count'].fillna(df['door_count'].mean(),inplace=True)
df['seat_count'].fillna(df['seat_count'].mean(),inplace=True)
# Out:
# C:\Users\Vidhya S\AppData\Local\Temp\ipykernel_27064\3043568502.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Distance '].fillna(df['Distance '].mean(),inplace=True)
# C:\Users\Vidhya S\AppData\Local\Temp\ipykernel_27064\3043568502.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# Price                  0
# dtype: int64

# %%
df.dtypes
# Out:
# Id                       int64
# Maker                   object
# model                   object
# Location                object
# Distance               float64
# Owner Type              object
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission            object
# door_count             float64
# seat_count             float64
# fuel_type               object
# Price                  float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Maker']=le.fit_transform(df['Maker'])
df['model']=le.fit_transform(df['model'])
df['Location']=le.fit_transform(df['Location'])
df['Owner Type']=le.fit_transform(df['Owner Type'])
df['transmission']=le.fit_transform(df['transmission'])
df['fuel_type']=le.fit_transform(df['fuel_type'])

# %%
df.dtypes
# Out:
# Id                       int64
# Maker                    int64
# model                    int64
# Location                 int64
# Distance               float64
# Owner Type               int64
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission             int64
# door_count             float64
# seat_count             float64
# fuel_type                int64
# Price                  float64
# dtype: object

# %%
z=(df-df.mean())/df.std()
z
# Out:
#              Id     Maker     model  Location  Distance   Owner Type  \
# 0     -1.732002  0.670435 -0.525374 -1.586813   0.000000    0.447061
# 1     -1.731938 -0.895159 -0.363218 -1.586813  -0.245191    1.340899
# 2     -1.731873 -1.286557  1.096184 -0.003090  -0.178200    1.340899
# 3     -1.731808  0.279036 -0.849686  1.263889  -0.185728    1.340899
# 4     -1.731743 -1.286557  1.420496  0.313655  -0.128557   -0.446777
# ...         ...       ...       ...       ...        ...         ...
# 53510  1.731743  0.670435 -0.525374 -0.319834  -0.239376   -0.446777
# 53511  1.731808  0.670435 -0.525374 -1.270068   0.473834   -0.446777
# 53512  1.731873 -1.286557  1.096184  1.580634  -0.253450    1.340899
# 53513  1.731938  1.061833 -1.660465  0.313655   4.041295    1.340899
# 53514  1.732002 -1.286557  1.420496  0.630400   0.174189   -1.340615
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# ...

# %%
df1=df[(z>-2)&(z<2)]
import matplotlib.pyplot as plt
df1.boxplot()
plt.show()

# %%
z=(df1-df1.mean())/df1.std()
z
# Out:
#              Id     Maker     model  Location  Distance   Owner Type  \
# 0     -1.732002  0.670435 -0.525374 -1.586813   0.151033    0.447061
# 1     -1.731938 -0.895159 -0.363218 -1.586813  -0.720740    1.340899
# 2     -1.731873 -1.286557  1.096184 -0.003090  -0.482555    1.340899
# 3     -1.731808  0.279036 -0.849686  1.263889  -0.509323    1.340899
# 4     -1.731743 -1.286557  1.420496  0.313655  -0.306050   -0.446777
# ...         ...       ...       ...       ...        ...         ...
# 53510  1.731743  0.670435 -0.525374 -0.319834  -0.700067   -0.446777
# 53511  1.731808  0.670435 -0.525374 -1.270068   1.835748   -0.446777
# 53512  1.731873 -1.286557  1.096184  1.580634  -0.750105    1.340899
# 53513  1.731938  1.061833 -1.660465  0.313655        NaN    1.340899
# 53514  1.732002 -1.286557  1.420496  0.630400   0.770363   -1.340615
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# ...

# %%
df2=df1[(z>-2)&(z<2)]
df2.boxplot()
plt.show()

# %%
z=(df2-df2.mean())/df2.std()
z
# Out:
#              Id     Maker     model  Location  Distance   Owner Type  \
# 0     -1.732002  0.670435 -0.525374 -1.586813   0.308111    0.447061
# 1     -1.731938 -0.895159 -0.363218 -1.586813  -0.715616    1.340899
# 2     -1.731873 -1.286557  1.096184 -0.003090  -0.435914    1.340899
# 3     -1.731808  0.279036 -0.849686  1.263889  -0.467348    1.340899
# 4     -1.731743 -1.286557  1.420496  0.313655  -0.228644   -0.446777
# ...         ...       ...       ...       ...        ...         ...
# 53510  1.731743  0.670435 -0.525374 -0.319834  -0.691339   -0.446777
# 53511  1.731808  0.670435 -0.525374 -1.270068   2.286477   -0.446777
# 53512  1.731873 -1.286557  1.096184  1.580634  -0.750099    1.340899
# 53513  1.731938  1.061833 -1.660465  0.313655        NaN    1.340899
# 53514  1.732002 -1.286557  1.420496  0.630400   1.035392   -1.340615
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# ...

# %%
df3=df2[(z>-2)&(z<2)]
df3.boxplot()
plt.show()

# %%
df3.isnull().sum()
# Out:
# Id                         0
# Maker                      0
# model                      0
# Location                   0
# Distance                4201
# Owner Type                 0
# manufacture_year        5832
# Age of car              5832
# engine_displacement     6224
# engine_power            6848
# Vroom Audit Rating         0
# transmission               0
# door_count             19707
# seat_count             14691
# fuel_type                  0
# Price                   6983
# dtype: int64

# %%
df3.dropna(inplace=True)

# %%
df3.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# Price                  0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
data=pd.DataFrame(ss.fit_transform(df3),columns=df3.columns)
data
# Out:
#              Id     Maker     model  Location  Distance   Owner Type  \
# 0     -1.741119  0.057172 -0.853033  1.257946  -0.253431    1.335791
# 1     -1.740989  0.515568 -0.549499 -0.954155  -0.842655   -1.341560
# 2     -1.740795  0.057172  0.209334 -0.638140  -0.743756   -1.341560
# 3     -1.740470  0.973964 -1.460100 -1.586183  -1.064162   -0.449109
# 4     -1.740276  0.515568  1.575235 -1.270169  -1.062502   -1.341560
# ...         ...       ...       ...       ...        ...         ...
# 19799  1.729004  0.973964 -1.763633  0.941931  -0.510291   -1.341560
# 19800  1.729134 -2.234806 -0.094199  1.257946   2.186773    1.335791
# 19801  1.729328  0.515568  0.361101 -0.322126  -0.860774   -1.341560
# 19802  1.729458  0.515568  0.361101  1.257946  -1.064162   -0.449109
# 19803  1.729782  0.515568 -0.549499 -0.322126  -0.523096   -0.449109
#
#        manufacture_year  Age of car  engine_displacement  engine_power  \
# ...

# %%
data.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'Vroom Audit Rating', 'transmission', 'door_count', 'seat_count',
#        'fuel_type', 'Price'],
#       dtype='object')

# %%
x=data[['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
       'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
       'Vroom Audit Rating', 'transmission', 'fuel_type','seat_count','door_count']]
y=data['Price']

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.score(x,y)
# Out:
# 0.7937356968882314

# %%
model.coef_
# Out:
# array([ 2.29427451e-03, -1.64285856e-01,  9.49725438e-02,  1.58735952e-03,
#        -3.73432063e-01,  2.31838706e-03,  1.71591146e-01, -1.71591146e-01,
#         1.13125350e-01,  4.57709816e-01,  3.03372658e-04, -1.15022391e-01,
#        -1.49258069e-01,  0.00000000e+00,  0.00000000e+00])

# %%
model.intercept_
# Out:
# np.float64(1.7708387683490536e-15)

# %%
y_predict=pd.DataFrame(model.predict(x))
y_predict
# Out:
#               0
# 0      0.606537
# 1      1.101632
# 2      0.813046
# 3     -0.757326
# 4      0.255639
# ...         ...
# 19799 -0.129267
# 19800  0.307566
# 19801 -0.003148
# 19802  0.077168
# 19803  0.100835
#
# [19804 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error

# %%
mse=mean_squared_error(y,y_predict)
mse
# Out:
# np.float64(0.20626430311176858)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mae=mean_absolute_error(y,y_predict)
mae
# Out:
# np.float64(0.35891698225094665)

# %%
#TO IMPORT TESTING DATA SET
dft=pd.read_csv("Test_Data_Set.csv")
dft
# Out:
#          Id    Maker    model    Location  Distance       Owner Type  \
# 0     11001    skoda  octavia      Mumbai   150000.0           First
# 1     11002    skoda    rapid  Coimbatore    29376.0           Third
# 2     11003    skoda  octavia  Coimbatore    30563.0          Second
# 3     11004     audi       q3       Delhi     8650.0  Fourth & Above
# 4     11005     audi       tt     Chennai     6400.0           Third
# ...     ...      ...      ...         ...        ...             ...
# 5610  16611    skoda  octavia      Mumbai   149976.0           First
# 5611  16612    skoda   superb   Ahmedabad   332000.0           First
# 5612  16613    skoda  octavia   Bangalore   230800.0          Second
# 5613  16614   nissan  qashqai      Jaipur    63480.0           Third
# 5614  16615  hyundai      i30      Jaipur    75000.0          Second
#
#       manufacture_year  Age of car  engine_displacement  engine_power  \
# ...

# %%
dft.isnull().sum()
# Out:
# Id                        0
# Maker                     0
# model                     0
# Location                  0
# Distance                128
# Owner Type                0
# manufacture_year          0
# Age of car                0
# engine_displacement       0
# engine_power            168
# body_type              5193
# Vroom Audit Rating        0
# transmission              0
# door_count              806
# seat_count              891
# fuel_type                 0
# dtype: int64

# %%
dft.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'body_type', 'Vroom Audit Rating', 'transmission', 'door_count',
#        'seat_count', 'fuel_type'],
#       dtype='object')

# %%
dft.drop(columns='body_type',inplace=True)

# %%
dft['Distance '].fillna(df['Distance '].mean(),inplace=True)
dft['engine_power'].fillna(df['engine_power'].mean(),inplace=True)
dft['door_count'].fillna(df['door_count'].mean(),inplace=True)
dft['seat_count'].fillna(df['seat_count'].mean(),inplace=True)
# Out:
# C:\Users\Vidhya S\AppData\Local\Temp\ipykernel_27064\3420777497.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dft['Distance '].fillna(df['Distance '].mean(),inplace=True)
# C:\Users\Vidhya S\AppData\Local\Temp\ipykernel_27064\3420777497.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
dft.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# dtype: int64

# %%
dft.duplicated().sum()
# Out:
# np.int64(0)

# %%
dft.dtypes
# Out:
# Id                       int64
# Maker                   object
# model                   object
# Location                object
# Distance               float64
# Owner Type              object
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission            object
# door_count             float64
# seat_count             float64
# fuel_type               object
# dtype: object

# %%
dft['Maker']=le.fit_transform(dft['Maker'])
dft['model']=le.fit_transform(dft['model'])
dft['Location']=le.fit_transform(dft['Location'])
dft['Owner Type']=le.fit_transform(dft['Owner Type'])
dft['transmission']=le.fit_transform(dft['transmission'])
dft['fuel_type']=le.fit_transform(dft['fuel_type'])

# %%
dft.dtypes
# Out:
# Id                       int64
# Maker                    int64
# model                    int64
# Location                 int64
# Distance               float64
# Owner Type               int64
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission             int64
# door_count             float64
# seat_count             float64
# fuel_type                int64
# dtype: object

# %%
dft.boxplot()
plt.show()

# %%
z=(dft-dft.mean())/dft.std()
z
# Out:
#             Id     Maker     model  Location  Distance   Owner Type  \
# 0    -1.731588  0.657003 -0.509377  1.277965   0.177328   -1.302147
# 1    -1.730971  0.657003  0.469122 -0.621812  -0.217755    1.345369
# 2    -1.730354  0.657003 -0.509377 -0.621812  -0.213867    0.462863
# 3    -1.729738 -1.713357 -0.183211 -0.305182  -0.285639   -0.419642
# 4    -1.729121 -1.713357  0.958371 -0.938441  -0.293009    1.345369
# ...        ...       ...       ...       ...        ...         ...
# 5610  1.729121  0.657003 -0.509377  1.277965   0.177249   -1.302147
# 5611  1.729738  0.657003  0.795288 -1.571700   0.773436   -1.302147
# 5612  1.730354  0.657003 -0.509377 -1.255071   0.441974    0.462863
# 5613  1.730971  0.261943  0.306039  0.328077  -0.106053    1.345369
# 5614  1.731588 -0.528177 -0.998627  0.328077  -0.068321    0.462863
#
#       manufacture_year  Age of car  engine_displacement  engine_power  \
# 0            -0.736224    0.736224            -0.200189     -0.546978
# ...

# %%
df4=dft[(z>-2)&(z<2)]
df4.boxplot()
plt.show()

# %%
z=(df4-df4.mean())/df4.std()
z
# Out:
#             Id     Maker     model  Location  Distance   Owner Type  \
# 0    -1.731588  0.657003 -0.509377  1.277965   0.896966   -1.302147
# 1    -1.730971  0.657003  0.469122 -0.621812  -0.686718    1.345369
# 2    -1.730354  0.657003 -0.509377 -0.621812  -0.671133    0.462863
# 3    -1.729738 -1.713357 -0.183211 -0.305182  -0.958831   -0.419642
# 4    -1.729121 -1.713357  0.958371 -0.938441  -0.988372    1.345369
# ...        ...       ...       ...       ...        ...         ...
# 5610  1.729121  0.657003 -0.509377  1.277965   0.896651   -1.302147
# 5611  1.729738  0.657003  0.795288 -1.571700   3.286461   -1.302147
# 5612  1.730354  0.657003 -0.509377 -1.255071   1.957797    0.462863
# 5613  1.730971  0.261943  0.306039  0.328077  -0.238963    1.345369
# 5614  1.731588 -0.528177 -0.998627  0.328077  -0.087716    0.462863
#
#       manufacture_year  Age of car  engine_displacement  engine_power  \
# 0            -1.163674    1.163674            -0.330625     -0.557893
# ...

# %%
df5=df4[(z>-2)&(z<2)]
df5.boxplot()
plt.show()

# %%
z=(df5-df5.mean())/df5.std()
z
# Out:
#             Id     Maker     model  Location  Distance   Owner Type  \
# 0    -1.731588  0.657003 -0.509377  1.277965   1.172130   -1.302147
# 1    -1.730971  0.657003  0.469122 -0.621812  -0.674016    1.345369
# 2    -1.730354  0.657003 -0.509377 -0.621812  -0.655849    0.462863
# 3    -1.729738 -1.713357 -0.183211 -0.305182  -0.991226   -0.419642
# 4    -1.729121 -1.713357  0.958371 -0.938441  -1.025663    1.345369
# ...        ...       ...       ...       ...        ...         ...
# 5610  1.729121  0.657003 -0.509377  1.277965   1.171763   -1.302147
# 5611  1.729738  0.657003  0.795288 -1.571700        NaN   -1.302147
# 5612  1.730354  0.657003 -0.509377 -1.255071   2.408771    0.462863
# 5613  1.730971  0.261943  0.306039  0.328077  -0.152055    1.345369
# 5614  1.731588 -0.528177 -0.998627  0.328077   0.024258    0.462863
#
#       manufacture_year  Age of car  engine_displacement  engine_power  \
# 0            -1.372554    1.372554            -0.151022     -0.533646
# ...

# %%
df6=df5[(z>-2)&(z<2)]
df6.boxplot()
plt.show()

# %%
df5.isnull().sum()
# Out:
# Id                        0
# Maker                     0
# model                     0
# Location                  0
# Distance                246
# Owner Type                0
# manufacture_year        485
# Age of car              485
# engine_displacement     540
# engine_power            559
# Vroom Audit Rating        0
# transmission              0
# door_count             1226
# seat_count              624
# fuel_type                 0
# dtype: int64

# %%
df5.dropna(inplace=True)
df5.isnull().sum()
# Out:
# Id                     0
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# manufacture_year       0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# door_count             0
# seat_count             0
# fuel_type              0
# dtype: int64

# %%
datat=pd.DataFrame(ss.fit_transform(df5),columns=df5.columns)

# %%
datat
# Out:
#             Id     Maker     model  Location  Distance   Owner Type  \
# 0    -1.733747  0.593675 -0.551031  1.260673   1.497254   -1.290101
# 1    -1.733129  0.593675  0.405852 -0.634571  -0.513424    1.345603
# 2    -1.731893 -1.906617 -0.232070 -0.318697  -0.858905   -0.411533
# 3    -1.729421 -1.906617 -0.232070 -1.266319  -0.703050    1.345603
# 4    -1.728803  0.593675 -0.551031 -1.266319  -0.998591   -0.411533
# ...        ...       ...       ...       ...        ...         ...
# 3240  1.728849 -1.489902  1.203256  1.260673   0.582644   -1.290101
# 3241  1.729467  0.593675 -1.348435 -0.002823   0.534454    1.345603
# 3242  1.731321  0.593675  0.724814  1.260673   1.702665   -0.411533
# 3243  1.733175  0.593675 -0.551031  1.260673   1.496854   -1.290101
# 3244  1.735647 -0.656471 -1.029473  0.313051   0.247081    0.467035
#
#       manufacture_year  Age of car  engine_displacement  engine_power  \
# 0            -1.653683    1.653683            -0.239912     -0.749900
# ...

# %%
datat.columns
# Out:
# Index(['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
#        'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
#        'Vroom Audit Rating', 'transmission', 'door_count', 'seat_count',
#        'fuel_type'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
X_test=datat[['Id', 'Maker', 'model', 'Location', 'Distance ', 'Owner Type',
       'manufacture_year', 'Age of car', 'engine_displacement', 'engine_power',
       'Vroom Audit Rating', 'transmission', 'fuel_type','seat_count','door_count']]

# %%
y_test_pred=pd.DataFrame(model.predict(X_test))
y_test_pred
# Out:
#              0
# 0    -1.890714
# 1     0.081820
# 2     1.641875
# 3     1.830591
# 4    -0.432817
# ...        ...
# 3240  0.931755
# 3241 -1.593224
# 3242 -0.088667
# 3243 -0.500141
# 3244 -0.780794
#
# [3245 rows x 1 columns]

# %%
final=pd.concat([dft[['Id']],y_test_pred],axis=1)
final
# Out:
#          Id         0
# 0     11001 -1.890714
# 1     11002  0.081820
# 2     11003  1.641875
# 3     11004  1.830591
# 4     11005 -0.432817
# ...     ...       ...
# 5610  16611       NaN
# 5611  16612       NaN
# 5612  16613       NaN
# 5613  16614       NaN
# 5614  16615       NaN
#
# [5615 rows x 2 columns]

# %%
final.to_csv('Prediction.csv')
